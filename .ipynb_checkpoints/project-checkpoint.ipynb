# %%
import pandas as pd
import numpy as np
import matplotlib, matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import seaborn as sns

# %%
df=pd.read_csv("./PreK_project.csv")
df.dropna(subset=['Student_ID'], how='all', inplace = True)

# %%
# We need to arrange our StudentID from float to int, and then to string
def convertToBetterIndex(df_t):
    strTbl=[]
    for a in df_t:
        strTbl.append(str(int(a)))
    return strTbl

# %%
df['Student_ID']=convertToBetterIndex(df['Student_ID'].values)
df.set_index('Student_ID', inplace=True)

# %%
# As you can see, here we have a duplicate, and this is preventing us to replicate the brochure plot.
# We will deal with this by removing this entry.
df.loc['164658334']
# Out:
#             Pre_No  TVEP Study  Fall_GRTR_Score  Fall_GRTR_Level  \
# Student_ID
# 164658334      1.0         NaN              0.0              1.0
# 164658334      NaN         NaN             14.0              1.0
#
#             Winter_GRTR_Score  Winter_GRTR_Level  Spring_GRTR_Score  \
# Student_ID
# 164658334                 0.0                1.0                0.0
# 164658334                18.0                2.0               23.0
#
#             Spring_GRTR_Level  Incomplete_IRI  Fall_LNF   ...    Spring_LNF  \
# Student_ID                                                ...
# 164658334                 1.0             NaN       NaN   ...           NaN
# 164658334                 2.0             NaN       NaN   ...           NaN
#
#             Spring_LNF_Level  Spring_LSF  Spring_LSF_Level  Spring_LNF_Growth  \
# Student_ID
# 164658334                NaN         NaN               NaN                NaN
# 164658334                NaN         NaN               NaN                NaN
#
#             Spring_LSF_Growth  am_pm  teacher  school  cohort
# Student_ID
# 164658334                 NaN    NaN      NaN     NaN     1.0
# 164658334                 NaN    NaN      NaN     NaN     2.0
#
# [2 rows x 28 columns]

# %%
# Removing duplicate entries in index
df = df[~df.index.duplicated(keep='first')]

# %%
students=['945765668', '577523557','142728168','325383322','514537372','532834342','275522143','236438768',
          '912457324','492575653','286764562','982494857','2358183654','273972562','127648521',
          '834171656','852221239','643655377','872582144','666683785','855745397','989538648','183837445',
          '983366665','164658334','854644586','923951547','853248442','945653567','386148753','672424336',
          '227388697','296549775','618975655','733624274','867823644','823135663']
# The following table contains all students that were part of the program prek
prekst=df.loc[students]

# %%
noprk = df.index.isin(students)
# The followint table contains students that were not in the prek program
nonprek=df[~noprk]

# %%
def getMean(dataset, indexStr):
    # Remove all Nan in row/index
    dataset.dropna(subset=[indexStr], how='all', inplace = True)
    col=dataset[indexStr]
    return col.mean()

# %% [markdown]
# <body>
#     <section style="background-color:White; font-family:Georgia;text-align:center">
#         <h2 style="font-family:Garamond; color:solid #229954">Result 1</h2>
#         <h3 style="font-family:Garamond;">Replicating results from Boise Pre-K Program Evaluation 2017</h3>
#         <h4 style="font-family:Garamond;">Page 7</h4>
#         <hr/>
#     </section>
# </body>

# %%
print("Fall LSF No Vista Pre-k = ", getMean(nonprek.copy(), 'Fall_LSF'))
print("Fall LSF Vista Pre-k = ", getMean(prekst.copy(), 'Fall_LSF'))
print("Fall LNF No Vista Pre-k = ", getMean(nonprek.copy(), 'Fall_LNF'))
print("Fall LNF Vista Pre-k = ", getMean(prekst.copy(), 'Fall_LNF'))
# Out:
# Fall LSF No Vista Pre-k =  6.3375
# Fall LSF Vista Pre-k =  13.409090909090908
# Fall LNF No Vista Pre-k =  16.2
# Fall LNF Vista Pre-k =  26.363636363636363

# %%
print("Winter LSF No Vista Pre-k = ", getMean(nonprek.copy(), 'Winter_LSF'))
print("Winter LSF Vista Pre-k = ", getMean(prekst.copy(), 'Winter_LSF'))
print("Winter LNF No Vista Pre-k = ", getMean(nonprek.copy(), 'Winter_LNF'))
print("Winter LNF Vista Pre-k = ", getMean(prekst.copy(), 'Winter_LNF'))
# Out:
# Winter LSF No Vista Pre-k =  25.22093023255814
# Winter LSF Vista Pre-k =  31.347826086956523
# Winter LNF No Vista Pre-k =  32.86046511627907
# Winter LNF Vista Pre-k =  36.52173913043478

# %%
print("Spring LSF No Vista Pre-k = ", getMean(nonprek.copy(), 'Spring_LSF'))
print("Spring LSF Vista Pre-k = ", getMean(prekst.copy(), 'Spring_LSF'))
print("Spring LNF No Vista Pre-k = ", getMean(nonprek.copy(), 'Spring_LNF'))
print("Spring LNF Vista Pre-k = ", getMean(prekst.copy(), 'Spring_LNF'))
# Out:
# Spring LSF No Vista Pre-k =  40.38297872340426
# Spring LSF Vista Pre-k =  45.0
# Spring LNF No Vista Pre-k =  41.07446808510638
# Spring LNF Vista Pre-k =  46.26086956521739

# %% [markdown]
# <body>
#     <section style="background-color:White; font-family:Georgia;text-align:center">
#         <h2 style="font-family:Garamond; color:solid #229954">Result 1</h2>
#         <h3 style="font-family:Garamond;">Replicating results from Boise Pre-K Program Evaluation 2017</h3>
#         <h4 style="font-family:Garamond;">Page 9</h4>
#         <hr/>
#     </section>
# </body>

# %%
# We need to arrange our StudentID from float to int, and then to string
def convertToInt(df_t):
    strTbl=[]
    for a in df_t:
        strTbl.append(int(a))
    return strTbl

# %%
def getListValues(dataset, firstSelector, secondSelector):
    tbl = dataset.reset_index()
    data = tbl.groupby([firstSelector])[[secondSelector]].count()
    data = data.reset_index()
    data['firstSelector']=convertToInt(data[firstSelector].values)
    return list(data[secondSelector])

# %%
def getBelowAverages(dataset):
    tbl = dataset.reset_index()
    data = tbl.groupby(['Fall_GRTR_Level'])[['Student_ID']].count()
    data = data.reset_index()
    data['Fall_GRTR_Level']=convertToInt(data['Fall_GRTR_Level'].values)
    fall = (list(data['Student_ID']))[0]
    
    data = tbl.groupby(['Winter_GRTR_Level'])[['Student_ID']].count()
    data = data.reset_index()
    data['Winter_GRTR_Level']=convertToInt(data['Winter_GRTR_Level'].values)
    winter = (list(data['Student_ID']))[0]
    
    data = tbl.groupby(['Spring_GRTR_Level'])[['Student_ID']].count()
    data = data.reset_index()
    data['Spring_GRTR_Level']=convertToInt(data['Spring_GRTR_Level'].values)
    spring = (list(data['Student_ID']))[0]
    
    return [fall, winter, spring]
def getAverages(dataset):
    tbl = dataset.reset_index()
    data = tbl.groupby(['Fall_GRTR_Level'])[['Student_ID']].count()
    data = data.reset_index()
    data['Fall_GRTR_Level']=convertToInt(data['Fall_GRTR_Level'].values)
    fall = (list(data['Student_ID']))[1]
    
    data = tbl.groupby(['Winter_GRTR_Level'])[['Student_ID']].count()
    data = data.reset_index()
    data['Winter_GRTR_Level']=convertToInt(data['Winter_GRTR_Level'].values)
    winter = (list(data['Student_ID']))[1]
    
    data = tbl.groupby(['Spring_GRTR_Level'])[['Student_ID']].count()
    data = data.reset_index()
    data['Spring_GRTR_Level']=convertToInt(data['Spring_GRTR_Level'].values)
    spring = (list(data['Student_ID']))[1]
    
    return [fall, winter, spring]
def getAboveAverages(dataset):
    tbl = dataset.reset_index()
    data = tbl.groupby(['Fall_GRTR_Level'])[['Student_ID']].count()
    data = data.reset_index()
    data['Fall_GRTR_Level']=convertToInt(data['Fall_GRTR_Level'].values)
    fall = (list(data['Student_ID']))[2]
    
    data = tbl.groupby(['Winter_GRTR_Level'])[['Student_ID']].count()
    data = data.reset_index()
    data['Winter_GRTR_Level']=convertToInt(data['Winter_GRTR_Level'].values)
    winter = (list(data['Student_ID']))[2]
    
    data = tbl.groupby(['Spring_GRTR_Level'])[['Student_ID']].count()
    data = data.reset_index()
    data['Spring_GRTR_Level']=convertToInt(data['Spring_GRTR_Level'].values)
    spring = (list(data['Student_ID']))[2]
    
    return [fall, winter, spring]

# %%
fig, ax = plt.subplots(figsize=(12, 7))
N = 3 #Number of groups
width = 0.40         # the width of the bars
ind = np.arange(N)    # the x locations for the groups

x=[0, 2, 4]
fall = getListValues(prekst.copy(), 'Fall_GRTR_Level','Student_ID')

ba = getBelowAverages(prekst.copy())
av = getAverages(prekst.copy())
aa = getAboveAverages(prekst.copy())

#ax = plt.figure().gca()
ax.yaxis.set_major_locator(MaxNLocator(integer=True))

p1 = ax.bar(x,ba, width, color='deepskyblue', bottom=0)
p2 = ax.bar(ind*2 + width , av, width,color='orangered')
p3 = ax.bar(ind*2 + width*2, aa, width,color='royalblue')

ax.set_title('Cohort 1 Get Ready To Read Levels (2015-2016)')
ax.set_xticks((ind*2) + width/2)
ax.set_xticklabels(('Fall', 'Winter', 'Spring'))
ax.set_ylabel('number of students')

ax.grid(True)
ax.legend((p1[0], p2[0], p3[0]), ('below average', 'average', 'above average'),loc='upper left')
ax.autoscale_view()
plt.show()

# %%
prekst
# Out:
#             Pre_No  TVEP Study  Fall_GRTR_Score  Fall_GRTR_Level  \
# Student_ID
# 945765668      1.0         NaN             17.0              2.0
# 577523557      1.0         NaN             14.0              2.0
# 142728168      1.0         NaN             18.0              2.0
# 325383322      1.0         NaN              5.0              1.0
# 514537372      1.0         NaN             16.0              2.0
# 532834342      1.0         NaN             14.0              2.0
# 275522143      1.0         NaN             18.0              2.0
# 236438768      1.0         NaN              3.0              1.0
# 912457324      1.0         NaN              7.0              1.0
# 492575653      1.0         0.0              1.0              1.0
# 286764562      1.0         NaN              NaN              NaN
# 982494857      1.0         0.0             11.0              1.0
# 2358183654     1.0         NaN              NaN              NaN
# 273972562      1.0         NaN              NaN              NaN
# 127648521      1.0         NaN             19.0              2.0
# 834171656      1.0         NaN             16.0              2.0
# 852221239      1.0         NaN             14.0              2.0
# 643655377      1.0         NaN             19.0              2.0
# 872582144      1.0         NaN             14.0              2.0
# 666683785      1.0         NaN             19.0              2.0
# 855745397      1.0         NaN             18.0              2.0
# 989538648      1.0         NaN             18.0              2.0
# 183837445      1.0         NaN              9.0              1.0
# 983366665      1.0         NaN             17.0              2.0
# 164658334      1.0         NaN              0.0              1.0
# 854644586      1.0         NaN             23.0              3.0
# 923951547      1.0         NaN             10.0              1.0
# 853248442      1.0         NaN             10.0              1.0
# 945653567      1.0         NaN             14.0              2.0
# 386148753      1.0         NaN              8.0              1.0
# 672424336      1.0         NaN             21.0              3.0
# 227388697      1.0         0.0              NaN              NaN
# 296549775      1.0         0.0              NaN              NaN
# 618975655      1.0         0.0              NaN              NaN
# 733624274      1.0         0.0              NaN              NaN
# 867823644      1.0         0.0              NaN              NaN
# 823135663      1.0         0.0              NaN              NaN
#
#             Winter_GRTR_Score  Winter_GRTR_Level  Spring_GRTR_Score  \
# Student_ID
# 945765668                20.0                2.0               22.0
# 577523557                16.0                2.0               22.0
# 142728168                21.0                3.0               25.0
# 325383322                17.0                2.0               22.0
# 514537372                20.0                2.0               23.0
# 532834342                14.0                1.0               18.0
# 275522143                18.0                2.0               22.0
# 236438768                 9.0                1.0               13.0
# 912457324                15.0                2.0               17.0
# 492575653                 5.0                1.0               10.0
# 286764562                 4.0                1.0               16.0
# 982494857                16.0                2.0               19.0
# 2358183654                7.0                1.0               18.0
# 273972562                11.0                1.0               19.0
# 127648521                20.0                2.0               23.0
# 834171656                19.0                3.0               24.0
# 852221239                15.0                1.0               19.0
# 643655377                17.0                2.0               22.0
# 872582144                18.0                2.0               22.0
# 666683785                24.0                3.0               23.0
# 855745397                23.0                3.0               25.0
# 989538648                22.0                3.0               24.0
# 183837445                 7.0                1.0               12.0
# 983366665                20.0                2.0               23.0
# 164658334                 0.0                1.0                0.0
# 854644586                24.0                3.0               25.0
# 923951547                15.0                2.0               22.0
# 853248442                13.0                1.0               18.0
# 945653567                21.0                2.0               24.0
# 386148753                 5.0                1.0               11.0
# 672424336                20.0                2.0               25.0
# 227388697                 NaN                NaN               21.0
# 296549775                21.0                3.0               24.0
# 618975655                23.0                3.0               21.0
# 733624274                18.0                2.0               21.0
# 867823644                 NaN                NaN               22.0
# 823135663                24.0                3.0               24.0
#
#             Spring_GRTR_Level  Incomplete_IRI  Fall_LNF   ...    Spring_LNF  \
# Student_ID                                                ...
# 945765668                 2.0             0.0      21.0   ...          35.0
# 577523557                 2.0             NaN       NaN   ...           NaN
# 142728168                 3.0             1.0       NaN   ...          42.0
# 325383322                 2.0             0.0      31.0   ...          29.0
# 514537372                 2.0             0.0      49.0   ...          81.0
# 532834342                 2.0             NaN       NaN   ...           NaN
# 275522143                 2.0             0.0      47.0   ...          66.0
# 236438768                 1.0             0.0      11.0   ...          37.0
# 912457324                 2.0             0.0      17.0   ...          16.0
# 492575653                 1.0             NaN       NaN   ...           NaN
# 286764562                 2.0             0.0       2.0   ...          27.0
# 982494857                 2.0             0.0      11.0   ...          19.0
# 2358183654                2.0             NaN       NaN   ...           NaN
# 273972562                 2.0             NaN       NaN   ...           NaN
# 127648521                 1.0             0.0      31.0   ...          45.0
# 834171656                 1.0             0.0      25.0   ...          43.0
# 852221239                 2.0             NaN       NaN   ...           NaN
# 643655377                 2.0             NaN       NaN   ...           NaN
# 872582144                 2.0             0.0       5.0   ...          49.0
# 666683785                 3.0             0.0      28.0   ...          39.0
# 855745397                 3.0             0.0      23.0   ...          44.0
# 989538648                 3.0             0.0      16.0   ...          41.0
# 183837445                 1.0             NaN       NaN   ...           NaN
# 983366665                 3.0             0.0      26.0   ...          55.0
# 164658334                 1.0             NaN       NaN   ...           NaN
# 854644586                 3.0             0.0      38.0   ...          69.0
# 923951547                 3.0             NaN       NaN   ...           NaN
# 853248442                 2.0             NaN       NaN   ...           NaN
# 945653567                 3.0             0.0      40.0   ...          74.0
# 386148753                 1.0             NaN       NaN   ...           NaN
# 672424336                 3.0             NaN       NaN   ...           NaN
# 227388697                 2.0             0.0      12.0   ...          52.0
# 296549775                 3.0             0.0      95.0   ...          84.0
# 618975655                 2.0             0.0      34.0   ...          50.0
# 733624274                 3.0             0.0      11.0   ...          25.0
# 867823644                 2.0             NaN       NaN   ...           NaN
# 823135663                 3.0             0.0       7.0   ...          42.0
#
#             Spring_LNF_Level  Spring_LSF  Spring_LSF_Level  Spring_LNF_Growth  \
# Student_ID
# 945765668                2.0        29.0               2.0               14.0
# 577523557                NaN         NaN               NaN                NaN
# 142728168                2.0        39.0               3.0               42.0
# 325383322                1.0        34.0               3.0                2.0
# 514537372                3.0        80.0               3.0               32.0
# 532834342                NaN         NaN               NaN                NaN
# 275522143                3.0        62.0               3.0               19.0
# 236438768                2.0        45.0               3.0               26.0
# 912457324                1.0        26.0               2.0                1.0
# 492575653                NaN         NaN               NaN                NaN
# 286764562                1.0        57.0               3.0               25.0
# 982494857                1.0        28.0               2.0                8.0
# 2358183654               NaN         NaN               NaN                NaN
# 273972562                NaN         NaN               NaN                NaN
# 127648521                3.0        34.0               3.0               14.0
# 834171656                3.0        43.0               3.0               18.0
# 852221239                NaN         NaN               NaN                NaN
# 643655377                NaN         NaN               NaN                NaN
# 872582144                3.0        42.0               3.0               44.0
# 666683785                2.0        35.0               3.0               11.0
# 855745397                3.0        41.0               3.0               21.0
# 989538648                2.0        43.0               3.0               25.0
# 183837445                NaN         NaN               NaN                NaN
# 983366665                3.0        57.0               3.0               29.0
# 164658334                NaN         NaN               NaN                NaN
# 854644586                3.0        74.0               3.0               31.0
# 923951547                NaN         NaN               NaN                NaN
# 853248442                NaN         NaN               NaN                NaN
# 945653567                3.0        61.0               3.0               34.0
# 386148753                NaN         NaN               NaN                NaN
# 672424336                NaN         NaN               NaN                NaN
# 227388697                3.0        34.0               3.0               40.0
# 296549775                3.0        68.0               3.0               11.0
# 618975655                3.0        41.0               3.0               16.0
# 733624274                1.0        19.0               2.0               14.0
# 867823644                NaN         NaN               NaN                NaN
# 823135663                2.0        43.0               3.0               35.0
#
#             Spring_LSF_Growth  am_pm  teacher  school  cohort
# Student_ID
# 945765668                21.0    0.0      1.0     0.0     1.0
# 577523557                 NaN    NaN      NaN     NaN     1.0
# 142728168                39.0    1.0      1.0     0.0     1.0
# 325383322                20.0    0.0      2.0     0.0     1.0
# 514537372                33.0    1.0      1.0     0.0     1.0
# 532834342                 NaN    NaN      NaN     NaN     1.0
# 275522143                35.0    1.0      1.0     0.0     1.0
# 236438768                40.0    1.0      2.0     0.0     1.0
# 912457324                22.0    0.0      2.0     0.0     1.0
# 492575653                 NaN    NaN      NaN     NaN     1.0
# 286764562                54.0    0.0      2.0     0.0     1.0
# 982494857                23.0    0.0      1.0     0.0     1.0
# 2358183654                NaN    NaN      NaN     NaN     1.0
# 273972562                 NaN    NaN      NaN     NaN     1.0
# 127648521                25.0    0.0      3.0     1.0     1.0
# 834171656                28.0    0.0      3.0     1.0     1.0
# 852221239                 NaN    NaN      NaN     NaN     1.0
# 643655377                 NaN    NaN      NaN     NaN     1.0
# 872582144                40.0    0.0      3.0     1.0     1.0
# 666683785                25.0    0.0      3.0     1.0     1.0
# 855745397                28.0    0.0      3.0     1.0     1.0
# 989538648                35.0    1.0      3.0     1.0     1.0
# 183837445                 NaN    NaN      NaN     NaN     1.0
# 983366665                35.0    1.0      3.0     1.0     1.0
# 164658334                 NaN    NaN      NaN     NaN     1.0
# 854644586                49.0    1.0      3.0     1.0     1.0
# 923951547                 NaN    NaN      NaN     NaN     1.0
# 853248442                 NaN    NaN      NaN     NaN     1.0
# 945653567                54.0    1.0      3.0     1.0     1.0
# 386148753                 NaN    NaN      NaN     NaN     1.0
# 672424336                 NaN    NaN      NaN     NaN     1.0
# 227388697                31.0    0.0      3.0     1.0     1.0
# 296549775                 8.0    0.0      3.0     1.0     1.0
# 618975655                37.0    0.0      3.0     1.0     1.0
# 733624274                18.0    1.0      2.0     0.0     1.0
# 867823644                 NaN    NaN      NaN     NaN     1.0
# 823135663                40.0    0.0      3.0     1.0     1.0
#
# [37 rows x 28 columns]

# %% [markdown]
# <body>
#     <section style="background-color:White; font-family:Georgia;text-align:center">
#         <h2 style="font-family:Garamond; color:solid #229954">Trending improvement in Get Ready To Read score</h2>
#         <h3 style="font-family:Garamond;">Question: Are students who start the pre-k program, show improvement from fall to spring on their Get Ready To Read scores?</h3>
#         <hr/>
#     </section>
# </body>

# %%
sns.pairplot(prekst, x_vars="Fall_GRTR_Score", y_vars="Spring_GRTR_Score",kind="reg")

# %%
sns.pairplot(nonprek, x_vars="Spring_GRTR_Level", y_vars="Spring_LNF",kind="reg")

# %%
sns.pairplot(prekst, x_vars="Fall_GRTR_Level", y_vars="Spring_LNF",kind="reg")

# %%
sns.pairplot(nonprek, x_vars="Fall_LNF_Level", y_vars="Spring_LNF_Level",kind="reg")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\sw\anaconda\envs\fastai\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Fall_LNF_Level'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-d1bef5271e5c> in <module>()
# ----> 1 sns.pairplot(nonprek, x_vars="Fall_LNF_Level", y_vars="Spring_LNF_Level",kind="reg")
#
# D:\sw\anaconda\envs\fastai\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2122     elif kind == "reg":
#    2123         from .regression import regplot  # Avoid circular import
# -> 2124         plotter(regplot, **plot_kws)
#    2125
#    2126     # Add a legend
#
# D:\sw\anaconda\envs\fastai\lib\site-packages\seaborn\axisgrid.py in map(self, func, **kwargs)
#    1338
#    1339                     color = self.palette[k] if kw_color is None else kw_color
# -> 1340                     func(data_k[x_var], data_k[y_var],
#    1341                          label=label_k, color=color, **kwargs)
#    1342
#
# D:\sw\anaconda\envs\fastai\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# D:\sw\anaconda\envs\fastai\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# D:\sw\anaconda\envs\fastai\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# D:\sw\anaconda\envs\fastai\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# D:\sw\anaconda\envs\fastai\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Fall_LNF_Level'

# %%
nonprek
# Out:
#             Pre_No  TVEP Study  Fall_GRTR_Score  Fall_GRTR_Level  \
# Student_ID
# 124282947      NaN         NaN              NaN              NaN
# 176343167      NaN         NaN              NaN              NaN
# 179283294      NaN         NaN              NaN              NaN
# 199474726      NaN         NaN              NaN              NaN
# 218834332      NaN         NaN              NaN              NaN
# 223994426      NaN         NaN              NaN              NaN
# 226168478      NaN         NaN              NaN              NaN
# 237662588      NaN         NaN              NaN              NaN
# 238778285      NaN         NaN              NaN              NaN
# 244386343      NaN         NaN              NaN              NaN
# 245185447      NaN         NaN              NaN              NaN
# 248495213      NaN         NaN              NaN              NaN
# 252468435      NaN         NaN              NaN              NaN
# 254157624      NaN         NaN              NaN              NaN
# 262787754      NaN         NaN              NaN              NaN
# 263582666      NaN         NaN              NaN              NaN
# 266273896      NaN         NaN              NaN              NaN
# 268855418      NaN         NaN              NaN              NaN
# 274786565      NaN         NaN              NaN              NaN
# 283764736      NaN         NaN              NaN              NaN
# 287569256      NaN         NaN              NaN              NaN
# 297445249      NaN         NaN              NaN              NaN
# 297844465      NaN         NaN              NaN              NaN
# 323555796      NaN         NaN              NaN              NaN
# 329262114      NaN         NaN              NaN              NaN
# 335171611      NaN         NaN              NaN              NaN
# 342258822      NaN         NaN              NaN              NaN
# 343494564      NaN         NaN              NaN              NaN
# 352763242      NaN         NaN              NaN              NaN
# 357266284      NaN         NaN              NaN              NaN
# ...            ...         ...              ...              ...
# 288548519      NaN         NaN             17.0              2.0
# 342276483      NaN         NaN              8.0              1.0
# 162151223      NaN         NaN             14.0              2.0
# 289272968      NaN         NaN             13.0              1.0
# 666289399      NaN         NaN             20.0              2.0
# 987788991      NaN         NaN             20.0              2.0
# 932567847      NaN         NaN             11.0              1.0
# 534221845      NaN         NaN             19.0              2.0
# 137516367      NaN         NaN             10.0              1.0
# 134347818      NaN         NaN             10.0              1.0
# 326845371      NaN         NaN             24.0              3.0
# 876344428      NaN         NaN             15.0              2.0
# 161779272      NaN         NaN             10.0              1.0
# 879749794      NaN         NaN             12.0              2.0
# 156332915      NaN         NaN             12.0              3.0
# 114633317      NaN         NaN             10.0              1.0
# 978872372      NaN         NaN              6.0              1.0
# 762623672      NaN         NaN             14.0              2.0
# 954455981      NaN         NaN             12.0              2.0
# 744252566      NaN         NaN             20.0              2.0
# 987385934      NaN         NaN              5.0              1.0
# 965178371      NaN         NaN             15.0              2.0
# 827628528      NaN         NaN             17.0              2.0
# 828867247      NaN         NaN             14.0              2.0
# 964478426      NaN         NaN             17.0              2.0
# 248483855      NaN         NaN             17.0              2.0
# 645634431      NaN         NaN             21.0              3.0
# 833335566      NaN         NaN             18.0              3.0
# 871281235      NaN         NaN             15.0              2.0
# 264474564      NaN         NaN              3.0              1.0
#
#             Winter_GRTR_Score  Winter_GRTR_Level  Spring_GRTR_Score  \
# Student_ID
# 124282947                 NaN                NaN                NaN
# 176343167                 NaN                NaN                NaN
# 179283294                 NaN                NaN                NaN
# 199474726                 NaN                NaN                NaN
# 218834332                 NaN                NaN                NaN
# 223994426                 NaN                NaN                NaN
# 226168478                 NaN                NaN                NaN
# 237662588                 NaN                NaN                NaN
# 238778285                 NaN                NaN                NaN
# 244386343                 NaN                NaN                NaN
# 245185447                 NaN                NaN                NaN
# 248495213                 NaN                NaN                NaN
# 252468435                 NaN                NaN                NaN
# 254157624                 NaN                NaN                NaN
# 262787754                 NaN                NaN                NaN
# 263582666                 NaN                NaN                NaN
# 266273896                 NaN                NaN                NaN
# 268855418                 NaN                NaN                NaN
# 274786565                 NaN                NaN                NaN
# 283764736                 NaN                NaN                NaN
# 287569256                 NaN                NaN                NaN
# 297445249                 NaN                NaN                NaN
# 297844465                 NaN                NaN                NaN
# 323555796                 NaN                NaN                NaN
# 329262114                 NaN                NaN                NaN
# 335171611                 NaN                NaN                NaN
# 342258822                 NaN                NaN                NaN
# 343494564                 NaN                NaN                NaN
# 352763242                 NaN                NaN                NaN
# 357266284                 NaN                NaN                NaN
# ...                       ...                ...                ...
# 288548519                16.0                2.0               22.0
# 342276483                12.0                1.0               18.0
# 162151223                15.0                2.0               22.0
# 289272968                20.0                2.0               23.0
# 666289399                22.0                2.0               24.0
# 987788991                21.0                2.0               22.0
# 932567847                20.0                2.0               23.0
# 534221845                21.0                2.0               22.0
# 137516367                22.0                3.0               22.0
# 134347818                18.0                2.0               19.0
# 326845371                23.0                3.0               24.0
# 876344428                22.0                3.0               23.0
# 161779272                16.0                2.0               18.0
# 879749794                13.0                2.0               17.0
# 156332915                 9.0                1.0               18.0
# 114633317                21.0                3.0               20.0
# 978872372                12.0                2.0               18.0
# 762623672                23.0                3.0               24.0
# 954455981                20.0                2.0               21.0
# 744252566                21.0                2.0               22.0
# 987385934                10.0                1.0               16.0
# 965178371                17.0                2.0               23.0
# 827628528                22.0                3.0               22.0
# 828867247                20.0                2.0               24.0
# 964478426                19.0                2.0               23.0
# 248483855                19.0                2.0               23.0
# 645634431                21.0                2.0               21.0
# 833335566                19.0                2.0               24.0
# 871281235                20.0                2.0               21.0
# 264474564                15.0                1.0                NaN
#
#             Spring_GRTR_Level  Incomplete_IRI  Fall_LNF   ...    Spring_LNF  \
# Student_ID                                                ...
# 124282947                 NaN             1.0       NaN   ...          39.0
# 176343167                 NaN             0.0      31.0   ...          55.0
# 179283294                 NaN             0.0      20.0   ...          53.0
# 199474726                 NaN             1.0       NaN   ...           9.0
# 218834332                 NaN             0.0      11.0   ...          23.0
# 223994426                 NaN             0.0      20.0   ...          50.0
# 226168478                 NaN             0.0      25.0   ...          37.0
# 237662588                 NaN             1.0       NaN   ...          38.0
# 238778285                 NaN             0.0       8.0   ...          12.0
# 244386343                 NaN             0.0       0.0   ...          52.0
# 245185447                 NaN             0.0      20.0   ...          32.0
# 248495213                 NaN             0.0       8.0   ...          58.0
# 252468435                 NaN             0.0      26.0   ...          53.0
# 254157624                 NaN             0.0      11.0   ...          76.0
# 262787754                 NaN             1.0       NaN   ...          62.0
# 263582666                 NaN             0.0      15.0   ...          39.0
# 266273896                 NaN             1.0       NaN   ...          44.0
# 268855418                 NaN             0.0       2.0   ...          26.0
# 274786565                 NaN             0.0       9.0   ...          36.0
# 283764736                 NaN             0.0      50.0   ...          39.0
# 287569256                 NaN             0.0       8.0   ...          50.0
# 297445249                 NaN             0.0       4.0   ...          25.0
# 297844465                 NaN             0.0      48.0   ...          47.0
# 323555796                 NaN             0.0      25.0   ...          36.0
# 329262114                 NaN             0.0      17.0   ...          31.0
# 335171611                 NaN             0.0       3.0   ...          42.0
# 342258822                 NaN             0.0       0.0   ...          15.0
# 343494564                 NaN             1.0       NaN   ...          28.0
# 352763242                 NaN             0.0       4.0   ...          17.0
# 357266284                 NaN             0.0      32.0   ...          82.0
# ...                       ...             ...       ...   ...           ...
# 288548519                 3.0             NaN       NaN   ...           NaN
# 342276483                 2.0             NaN       NaN   ...           NaN
# 162151223                 3.0             NaN       NaN   ...           NaN
# 289272968                 2.0             NaN       NaN   ...           NaN
# 666289399                 3.0             NaN       NaN   ...           NaN
# 987788991                 2.0             NaN       NaN   ...           NaN
# 932567847                 3.0             NaN       NaN   ...           NaN
# 534221845                 2.0             NaN       NaN   ...           NaN
# 137516367                 2.0             NaN       NaN   ...           NaN
# 134347818                 2.0             NaN       NaN   ...           NaN
# 326845371                 3.0             NaN       NaN   ...           NaN
# 876344428                 3.0             NaN       NaN   ...           NaN
# 161779272                 2.0             NaN       NaN   ...           NaN
# 879749794                 2.0             NaN       NaN   ...           NaN
# 156332915                 2.0             NaN       NaN   ...           NaN
# 114633317                 2.0             NaN       NaN   ...           NaN
# 978872372                 2.0             NaN       NaN   ...           NaN
# 762623672                 3.0             NaN       NaN   ...           NaN
# 954455981                 3.0             NaN       NaN   ...           NaN
# 744252566                 2.0             NaN       NaN   ...           NaN
# 987385934                 2.0             NaN       NaN   ...           NaN
# 965178371                 3.0             NaN       NaN   ...           NaN
# 827628528                 2.0             NaN       NaN   ...           NaN
# 828867247                 3.0             NaN       NaN   ...           NaN
# 964478426                 2.0             NaN       NaN   ...           NaN
# 248483855                 2.0             NaN       NaN   ...           NaN
# 645634431                 2.0             NaN       NaN   ...           NaN
# 833335566                 3.0             NaN       NaN   ...           NaN
# 871281235                 2.0             NaN       NaN   ...           NaN
# 264474564                 NaN             NaN       NaN   ...           NaN
#
#             Spring_LNF_Level  Spring_LSF  Spring_LSF_Level  Spring_LNF_Growth  \
# Student_ID
# 124282947                2.0        68.0               3.0               39.0
# 176343167                3.0        48.0               3.0               24.0
# 179283294                3.0        47.0               3.0               33.0
# 199474726                1.0        43.0               3.0                9.0
# 218834332                1.0        28.0               2.0               12.0
# 223994426                3.0        57.0               3.0               30.0
# 226168478                2.0        56.0               3.0               12.0
# 237662588                2.0        50.0               3.0               38.0
# 238778285                1.0        20.0               2.0                4.0
# 244386343                3.0        43.0               3.0               52.0
# 245185447                2.0        29.0               2.0               12.0
# 248495213                3.0        50.0               3.0               50.0
# 252468435                3.0        56.0               3.0               27.0
# 254157624                3.0       100.0               3.0               65.0
# 262787754                3.0        53.0               3.0               62.0
# 263582666                2.0        35.0               3.0               24.0
# 266273896                3.0        48.0               3.0               44.0
# 268855418                1.0        14.0               1.0               24.0
# 274786565                2.0        21.0               2.0               27.0
# 283764736                2.0        48.0               3.0               11.0
# 287569256                3.0        56.0               3.0               42.0
# 297445249                1.0        20.0               2.0               21.0
# 297844465                3.0        34.0               3.0                1.0
# 323555796                2.0        36.0               3.0               11.0
# 329262114                2.0        46.0               3.0               14.0
# 335171611                2.0        31.0               3.0               39.0
# 342258822                1.0        11.0               1.0               15.0
# 343494564                1.0        39.0               3.0               28.0
# 352763242                1.0        20.0               2.0               13.0
# 357266284                3.0        83.0               3.0               50.0
# ...                      ...         ...               ...                ...
# 288548519                NaN         NaN               NaN                NaN
# 342276483                NaN         NaN               NaN                NaN
# 162151223                NaN         NaN               NaN                NaN
# 289272968                NaN         NaN               NaN                NaN
# 666289399                NaN         NaN               NaN                NaN
# 987788991                NaN         NaN               NaN                NaN
# 932567847                NaN         NaN               NaN                NaN
# 534221845                NaN         NaN               NaN                NaN
# 137516367                NaN         NaN               NaN                NaN
# 134347818                NaN         NaN               NaN                NaN
# 326845371                NaN         NaN               NaN                NaN
# 876344428                NaN         NaN               NaN                NaN
# 161779272                NaN         NaN               NaN                NaN
# 879749794                NaN         NaN               NaN                NaN
# 156332915                NaN         NaN               NaN                NaN
# 114633317                NaN         NaN               NaN                NaN
# 978872372                NaN         NaN               NaN                NaN
# 762623672                NaN         NaN               NaN                NaN
# 954455981                NaN         NaN               NaN                NaN
# 744252566                NaN         NaN               NaN                NaN
# 987385934                NaN         NaN               NaN                NaN
# 965178371                NaN         NaN               NaN                NaN
# 827628528                NaN         NaN               NaN                NaN
# 828867247                NaN         NaN               NaN                NaN
# 964478426                NaN         NaN               NaN                NaN
# 248483855                NaN         NaN               NaN                NaN
# 645634431                NaN         NaN               NaN                NaN
# 833335566                NaN         NaN               NaN                NaN
# 871281235                NaN         NaN               NaN                NaN
# 264474564                NaN         NaN               NaN                NaN
#
#             Spring_LSF_Growth  am_pm  teacher  school  cohort
# Student_ID
# 124282947                68.0    1.0      1.0     0.0     1.0
# 176343167                34.0    0.0      2.0     0.0     1.0
# 179283294                39.0    0.0      3.0     1.0     1.0
# 199474726                43.0    0.0      1.0     0.0     1.0
# 218834332                28.0    1.0      1.0     0.0     1.0
# 223994426                56.0    0.0      1.0     0.0     1.0
# 226168478                51.0    0.0      2.0     0.0     1.0
# 237662588                50.0    0.0      1.0     0.0     1.0
# 238778285                18.0    0.0      2.0     0.0     1.0
# 244386343                43.0    0.0      1.0     0.0     1.0
# 245185447                26.0    0.0      1.0     0.0     1.0
# 248495213                47.0    0.0      3.0     1.0     1.0
# 252468435                35.0    0.0      1.0     0.0     1.0
# 254157624                96.0    1.0      1.0     0.0     1.0
# 262787754                53.0    1.0      3.0     1.0     1.0
# 263582666                22.0    1.0      3.0     1.0     1.0
# 266273896                48.0    0.0      3.0     1.0     1.0
# 268855418                14.0    1.0      1.0     0.0     1.0
# 274786565                15.0    0.0      2.0     0.0     1.0
# 283764736                28.0    0.0      2.0     0.0     1.0
# 287569256                55.0    0.0      1.0     0.0     1.0
# 297445249                19.0    0.0      1.0     0.0     1.0
# 297844465                 6.0    0.0      2.0     0.0     1.0
# 323555796                32.0    0.0      3.0     1.0     1.0
# 329262114                46.0    1.0      3.0     1.0     1.0
# 335171611                30.0    0.0      2.0     0.0     1.0
# 342258822                11.0    0.0      1.0     0.0     1.0
# 343494564                39.0    1.0      1.0     0.0     1.0
# 352763242                18.0    1.0      2.0     0.0     1.0
# 357266284                71.0    0.0      3.0     1.0     1.0
# ...                       ...    ...      ...     ...     ...
# 288548519                 NaN    NaN      NaN     NaN     2.0
# 342276483                 NaN    NaN      NaN     NaN     2.0
# 162151223                 NaN    NaN      NaN     NaN     2.0
# 289272968                 NaN    NaN      NaN     NaN     2.0
# 666289399                 NaN    NaN      NaN     NaN     2.0
# 987788991                 NaN    NaN      NaN     NaN     2.0
# 932567847                 NaN    NaN      NaN     NaN     2.0
# 534221845                 NaN    NaN      NaN     NaN     2.0
# 137516367                 NaN    NaN      NaN     NaN     2.0
# 134347818                 NaN    NaN      NaN     NaN     2.0
# 326845371                 NaN    NaN      NaN     NaN     2.0
# 876344428                 NaN    NaN      NaN     NaN     2.0
# 161779272                 NaN    NaN      NaN     NaN     2.0
# 879749794                 NaN    NaN      NaN     NaN     2.0
# 156332915                 NaN    NaN      NaN     NaN     2.0
# 114633317                 NaN    NaN      NaN     NaN     2.0
# 978872372                 NaN    NaN      NaN     NaN     2.0
# 762623672                 NaN    NaN      NaN     NaN     2.0
# 954455981                 NaN    NaN      NaN     NaN     2.0
# 744252566                 NaN    NaN      NaN     NaN     2.0
# 987385934                 NaN    NaN      NaN     NaN     2.0
# 965178371                 NaN    NaN      NaN     NaN     2.0
# 827628528                 NaN    NaN      NaN     NaN     2.0
# 828867247                 NaN    NaN      NaN     NaN     2.0
# 964478426                 NaN    NaN      NaN     NaN     2.0
# 248483855                 NaN    NaN      NaN     NaN     2.0
# 645634431                 NaN    NaN      NaN     NaN     2.0
# 833335566                 NaN    NaN      NaN     NaN     2.0
# 871281235                 NaN    NaN      NaN     NaN     2.0
# 264474564                 NaN    NaN      NaN     NaN     2.0
#
# [141 rows x 28 columns]
